# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./OpenSource/train_top50000.csv', index_col=0, encoding = 'utf-8')

# %%
data
# Out:
#                                                     name  price  \
# 0                                2 TONE ARCH HOODIE GRAY  59250
# 1                                           하프 터틀넥 니트 세트  39900
# 2                              캐시미어 블렌드 리브드 크루 넥 니트 [블랙]  39090
# 3      (BY P.E.DEPT) UNIVERSITY HANDSOME DAN CREWNECK...  54000
# 4                           [유아인 착용 상품] 미니멀 크루 넥 니트 [블랙]  59900
# ...                                                  ...    ...
# 50031                                   로고 사이드립 후드 (네이비)  54000
# 50032                          KMC0017 스핑크스캣 기모 맨투맨 - 크림  54400
# 50033                           KMB0021 켈틱스컬 기모 맨투맨 - 블랙  54400
# 50034                          KMB0029 롯트와일러 기모 맨투맨 - 블랙  54400
# 50035                           KMB0004 칸레터링 기모 맨투맨 - 블랙  54400
#
#                                                url  \
# 0      https://store.musinsa.com/app/goods/1628385
# 1      https://store.musinsa.com/app/goods/1558847
# ...

# %%
len(data)
# Out:
# 50036

# %%
data['label'] = data.index
#for i in range(len(data)) :
print(data)
# Out:
#                                                     name  price  \
# 0                                2 TONE ARCH HOODIE GRAY  59250
# 1                                           하프 터틀넥 니트 세트  39900
# 2                              캐시미어 블렌드 리브드 크루 넥 니트 [블랙]  39090
# 3      (BY P.E.DEPT) UNIVERSITY HANDSOME DAN CREWNECK...  54000
# 4                           [유아인 착용 상품] 미니멀 크루 넥 니트 [블랙]  59900
# ...                                                  ...    ...
# 50031                                   로고 사이드립 후드 (네이비)  54000
# 50032                          KMC0017 스핑크스캣 기모 맨투맨 - 크림  54400
# 50033                           KMB0021 켈틱스컬 기모 맨투맨 - 블랙  54400
# 50034                          KMB0029 롯트와일러 기모 맨투맨 - 블랙  54400
# 50035                           KMB0004 칸레터링 기모 맨투맨 - 블랙  54400
#
#                                                url  \
# 0      https://store.musinsa.com/app/goods/1628385
# 1      https://store.musinsa.com/app/goods/1558847
# ...

# %%
data
# Out:
#                                                     name  price  \
# 0                                2 TONE ARCH HOODIE GRAY  59250
# 1                                           하프 터틀넥 니트 세트  39900
# 2                              캐시미어 블렌드 리브드 크루 넥 니트 [블랙]  39090
# 3      (BY P.E.DEPT) UNIVERSITY HANDSOME DAN CREWNECK...  54000
# 4                           [유아인 착용 상품] 미니멀 크루 넥 니트 [블랙]  59900
# ...                                                  ...    ...
# 50031                                   로고 사이드립 후드 (네이비)  54000
# 50032                          KMC0017 스핑크스캣 기모 맨투맨 - 크림  54400
# 50033                           KMB0021 켈틱스컬 기모 맨투맨 - 블랙  54400
# 50034                          KMB0029 롯트와일러 기모 맨투맨 - 블랙  54400
# 50035                           KMB0004 칸레터링 기모 맨투맨 - 블랙  54400
#
#                                                url  \
# 0      https://store.musinsa.com/app/goods/1628385
# 1      https://store.musinsa.com/app/goods/1558847
# ...

# %%
data.to_csv("train_label_top50000.csv", encoding = 'utf-8')
